# %% [markdown]
# ## CÉLULA 1: IMPORTANDO AS BIBLIOTECAS

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import torch.optim as optim
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## DEFINIÇÃO DO CONSTRUTOR DA CLASSE

# %%
class MLPClassifier:
    def __init__(self, hidden_layers=[64, 32], activation='relu', learning_rate=0.01,
                 epochs=100, patience=5, batch_seze=32, optimizer='adam', regularization=None,
                 dropout_p=0.1, lamba_12=0.001, random_state=None):
        
        """
        Inicializa o classificador MLP para problemas multiclasse.

        Parametros:
        - hidden_layers: lista com numero de neuronios em casa camada oculta
        - activation: funcao de ativacao ('relu' ou 'tanh')
        - learning_rate: taxa de aprendizado
        """
